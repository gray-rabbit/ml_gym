# %% [markdown]
# ### Matplotlib 데이터 시각화
#
# python에서 정적, 애니메이션 및 대화형 시각화를 만들기 위한 라이브러리

# %%
#설치 명령어
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#임포트
import matplotlib.pyplot as plt #보통 plt로 축약해서 사용

# %%
#plot 그리기
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4])
plt.ylabel("some number")
plt.xlabel("한글은??")#한글은 지원하지 않습니다.
# Out:
# Text(0.5, 0, '한글은??')
# f:\python_workspace\ml_gym\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\python_workspace\ml_gym\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\python_workspace\ml_gym\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#서식 지정
import numpy as np
x = np.arange(5)
y = x**2
plt.plot(x,y, "y.:",x,x**3,"r.--")
plt.plot(x,x**4,"g^-")
# [marker][line][color] 순이 원래 공식이긴한데...
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
#여러 축 배열
x = np.arange(-1,1.1,.1)
fig, ax = plt.subplots(2,2)
fig.set_size_inches(10,5)
ax[0][0].plot(x)
ax[0][1].plot(x+1)
ax[1][0].plot(x*2)
ax[1][1].plot(x,np.sin(x*np.pi),x,np.cos(x*np.pi),"r.:")

# %%
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)


t1 = np.arange(0., 5., .1)
t2 = np.arange(0., 5., .02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1),"bo", t2,f(t2),'y')
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2),'r--')

# %%
#범례
fig, ax = plt.subplots()
line_up, = ax.plot([1, 2, 3], label='Line 2')
line_down, = ax.plot([3, 2, 1], label='Line 1')
# ax.legend(handles=[line_up, line_down])

# %%
fig, ax = plt.subplots()
line_up, = ax.plot([1, 2, 3], label='Line 2')
line_down, = ax.plot([3, 2, 1], label='Line 1')
ax.legend([line_up, line_down], ['Line Up', 'Line Down'])

# %%
#scatter

x = np.random.standard_normal(1000)
y = np.random.standard_normal(1000)
plt.scatter(x,y)

# %%
#scatter

x = np.random.randn(100000)
y = np.random.randn(100000)
plt.scatter(x,y)

# %%
#추가 히스토그램
# plt.hist([2,3,1,1,2,2,3,3,3,3,],bins=5)

a = np.random.randn(10000)
b = np.random.standard_normal(10000)
plt.hist(a,bins=100,color="r",density=True)
plt.hist(b,bins=100,alpha=.3,color="b",density=True)
# Out:
# (array([0.00128762, 0.00128762, 0.00128762, 0.00257524, 0.        ,
#         0.00128762, 0.        , 0.00128762, 0.00257524, 0.0064381 ,
#         0.00386286, 0.00386286, 0.01158859, 0.0064381 , 0.01030097,
#         0.01030097, 0.02060193, 0.02575242, 0.03219052, 0.03862862,
#         0.02704004, 0.04635435, 0.037341  , 0.05408007, 0.06051818,
#         0.08112011, 0.09270869, 0.09270869, 0.12876208, 0.14163828,
#         0.19314311, 0.18155453, 0.15837735, 0.21503267, 0.2291965 ,
#         0.23434698, 0.25494891, 0.28327657, 0.3038785 , 0.32061757,
#         0.3103166 , 0.33864426, 0.32963092, 0.3347814 , 0.41718913,
#         0.39143671, 0.41203864, 0.41976437, 0.40045006, 0.41203864,
#         0.39529957, 0.37727288, 0.35409571, 0.38886147, 0.33220616,
#         0.35152047, 0.34250712, 0.30774136, 0.30774136, 0.29228991,
#         0.24593557, 0.23177174, 0.21116981, 0.20859456, 0.17769167,
#         0.1609526 , 0.1673907 , 0.10687252, 0.12747446, 0.11073539,
# ...

# %%
#imshow 는 opencv와 함께합니다.
